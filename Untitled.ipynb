# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y,)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10)

plt.plot(x,x*1.5,'go:',x,x*2.5,'rx',x,x*3.5,'^',x,x*4.5,'bd-.')
# Out:
# [<matplotlib.lines.Line2D at 0x28001aae8c8>,
#  <matplotlib.lines.Line2D at 0x28001ac3288>,
#  <matplotlib.lines.Line2D at 0x28001ac3448>,
#  <matplotlib.lines.Line2D at 0x28001ac3788>]
