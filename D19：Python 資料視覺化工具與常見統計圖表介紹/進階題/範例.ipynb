# %% [markdown]
# 範例目標:<br>
# 1. 實做繪製圖表
# 2. 藉由圖表對資料有初步認識，並解釋圖表意義

# %% [markdown]
# 範例重點:<br>
# 1. 每一種圖表都有相對應用的情境，分辨情境並繪製對應圖表
# 2. 圖像化展現，方便對於資料有初步的理解

# %%
import pandas as pd
import numpy as np

# %%
#單一折線圖
ts = pd.Series(np.random.randn(200), index=pd.date_range('1/1/2020', periods=200 , freq = 'D'))
ts = ts.cumsum()
print(ts)
ts.plot()
# Out:
# 2020-01-01    1.663923
# 2020-01-02    2.868334
# 2020-01-03    3.860759
# 2020-01-04    5.094154
# 2020-01-05    5.405889
#                 ...
# 2020-07-14    7.434333
# 2020-07-15    7.992114
# 2020-07-16    8.702238
# 2020-07-17    8.710750
# 2020-07-18    9.188072
# Freq: D, Length: 200, dtype: float64
# <AxesSubplot:>

# %%
#多個折線圖同時畫出
df = pd.DataFrame(np.random.randn(200, 3), index=pd.date_range('1/1/2020', periods=200), columns=["A","B","C"])
df = df.cumsum()
print(df)
df.plot();
# Out:
#                    A         B         C
# 2020-01-01 -0.179860  1.921109  1.050646
# 2020-01-02 -0.256326  2.212462  0.977120
# 2020-01-03 -0.649680  2.646760  2.847519
# 2020-01-04 -0.139450  1.943572  2.108917
# 2020-01-05  0.688769  3.075844  3.635317
# ...              ...       ...       ...
# 2020-07-14 -2.908388 -6.157917  7.114893
# 2020-07-15 -2.180876 -7.732527  7.290495
# 2020-07-16 -2.334964 -8.205450  6.147158
# 2020-07-17 -2.460052 -9.093785  6.291407
# 2020-07-18 -2.256323 -9.928113  4.993201
#
# [200 rows x 3 columns]

# %%
#圓餅圖
df = pd.Series(np.random.rand(4), index=["A","B","C","D"],name="title")
print(df)
df.plot.pie()
# Out:
# A    0.671026
# B    0.601189
# C    0.478511
# D    0.932186
# Name: title, dtype: float64

# %%
#長條圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.bar();
# Out:
#           A         B
# 0  0.351182  0.318318
# 1  0.897806  0.003340
# 2  0.632099  0.567870
# 3  0.772415  0.441826
# 4  0.570837  0.476311
# 5  0.282301  0.974770
# 6  0.582213  0.884616
# 7  0.904212  0.543904
# 8  0.734159  0.452428
# 9  0.475335  0.328955

# %%
df.plot.bar(stacked=True);

# %%
#箱型圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.boxplot()
# Out:
#           A         B
# 0  0.772122  0.297662
# 1  0.150642  0.919099
# 2  0.761859  0.444911
# 3  0.461002  0.876932
# 4  0.374707  0.214824
# 5  0.674743  0.192699
# 6  0.667188  0.921153
# 7  0.353126  0.343032
# 8  0.436113  0.929506
# 9  0.327474  0.935201

# %%
#散佈圖
df = pd.DataFrame(np.random.rand(10, 2), columns=["A","B"])
print(df)
df.plot.scatter(x='A', y='B')
# Out:
#           A         B
# 0  0.810470  0.246334
# 1  0.752608  0.276965
# 2  0.424421  0.409977
# 3  0.909217  0.079332
# 4  0.376237  0.578638
# 5  0.603542  0.460691
# 6  0.039021  0.572284
# 7  0.499532  0.239554
# 8  0.526853  0.967803
# 9  0.077156  0.949759
